# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from scipy.stats import chi2_contingency
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, precision_recall_fscore_support
import warnings
import os

# %%
df = pd.read_csv('C:/Users/dell/Documents/Data science/campusX/project/credit risk modeling/data_for_model.csv')

df_encoded = df.copy()
df_encoded.shape
# Out:
# (41500, 55)

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41500 entries, 0 to 41499
# Data columns (total 55 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   pct_tl_open_L6M               41500 non-null  float64
#  1   pct_tl_closed_L6M             41500 non-null  float64
#  2   Tot_TL_closed_L12M            41500 non-null  int64
#  3   pct_tl_closed_L12M            41500 non-null  float64
#  4   Tot_Missed_Pmnt               41500 non-null  int64
#  5   CC_TL                         41500 non-null  int64
#  6   Home_TL                       41500 non-null  int64
#  7   PL_TL                         41500 non-null  int64
#  8   Secured_TL                    41500 non-null  int64
#  9   Unsecured_TL                  41500 non-null  int64
#  10  Other_TL                      41500 non-null  int64
#  11  Age_Oldest_TL                 41500 non-null  int64
#  12  Age_Newest_TL                 41500 non-null  int64
#  13  time_since_recent_payment     41500 non-null  int64
#  14  max_recent_level_of_deliq     41500 non-null  int64
#  15  num_deliq_6_12mts             41500 non-null  int64
#  16  num_times_60p_dpd             41500 non-null  int64
#  17  num_std_12mts                 41500 non-null  int64
#  18  num_sub                       41500 non-null  int64
#  19  num_sub_6mts                  41500 non-null  int64
#  20  num_sub_12mts                 41500 non-null  int64
#  21  num_dbt                       41500 non-null  int64
#  22  num_dbt_12mts                 41500 non-null  int64
#  23  num_lss                       41500 non-null  int64
#  24  recent_level_of_deliq         41500 non-null  int64
#  25  CC_enq_L12m                   41500 non-null  int64
#  26  PL_enq_L12m                   41500 non-null  int64
#  27  time_since_recent_enq         41500 non-null  int64
#  28  enq_L3m                       41500 non-null  int64
#  29  NETMONTHLYINCOME              41500 non-null  int64
#  30  Time_With_Curr_Empr           41500 non-null  int64
#  31  CC_Flag                       41500 non-null  int64
#  32  PL_Flag                       41500 non-null  int64
#  33  pct_PL_enq_L6m_of_ever        41500 non-null  float64
#  34  pct_CC_enq_L6m_of_ever        41500 non-null  float64
#  35  HL_Flag                       41500 non-null  int64
#  36  GL_Flag                       41500 non-null  int64
#  37  EDUCATION                     41500 non-null  int64
#  38  Approved_Flag                 41500 non-null  object
#  39  MARITALSTATUS_Married         41500 non-null  int64
#  40  MARITALSTATUS_Single          41500 non-null  int64
#  41  GENDER_F                      41500 non-null  int64
#  42  GENDER_M                      41500 non-null  int64
#  43  last_prod_enq2_AL             41500 non-null  int64
#  44  last_prod_enq2_CC             41500 non-null  int64
#  45  last_prod_enq2_ConsumerLoan   41500 non-null  int64
#  46  last_prod_enq2_HL             41500 non-null  int64
#  47  last_prod_enq2_PL             41500 non-null  int64
#  48  last_prod_enq2_others         41500 non-null  int64
#  49  first_prod_enq2_AL            41500 non-null  int64
#  50  first_prod_enq2_CC            41500 non-null  int64
#  51  first_prod_enq2_ConsumerLoan  41500 non-null  int64
#  52  first_prod_enq2_HL            41500 non-null  int64
#  53  first_prod_enq2_PL            41500 non-null  int64
#  54  first_prod_enq2_others        41500 non-null  int64
# dtypes: float64(5), int64(49), object(1)
# memory usage: 17.4+ MB

# %%
# Machine Learing model fitting

# Data processing

# 1. Random Forest

y = df_encoded['Approved_Flag']
x = df_encoded.drop( ['Approved_Flag'], axis = 1 )

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
rf_classifier = RandomForestClassifier(n_estimators = 200, random_state=42)

rf_classifier.fit(x_train, y_train)

y_pred = rf_classifier.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print ()
print(f'Accuracy: {accuracy}')
print ()
precision, recall, f1_score, _ = precision_recall_fscore_support(y_test, y_pred)

for i, v in enumerate(['p1', 'p2', 'p3', 'p4']):
    print(f"Class {v}:")
    print(f"Precision: {precision[i]}")
    print(f"Recall: {recall[i]}")
    print(f"F1 Score: {f1_score[i]}")
    print()
# Out:
# Accuracy: 0.7646987951807229
#
# Class p1:
# Precision: 0.8152046783625732
# Recall: 0.7033299697275479
# F1 Score: 0.7551462621885157
#
# Class p2:
# Precision: 0.7947133539306557
# Recall: 0.9265559335601361
# F1 Score: 0.855585327543195
#
# Class p3:
# Precision: 0.45923460898502494
# Recall: 0.21495327102803738
# F1 Score: 0.2928381962864722
#
# Class p4:
# Precision: 0.730844793713163
# Recall: 0.7237354085603113
# F1 Score: 0.7272727272727273

# %%
# 2. xgboost

import xgboost as xgb
from sklearn.preprocessing import LabelEncoder

xgb_classifier = xgb.XGBClassifier(objective='multi:softmax',  num_class=4)

y = df_encoded['Approved_Flag']
x = df_encoded. drop ( ['Approved_Flag'], axis = 1 )

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)


x_train, x_test, y_train, y_test = train_test_split(x, y_encoded, test_size=0.2, random_state=42)

xgb_classifier.fit(x_train, y_train)
y_pred = xgb_classifier.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print ()
print(f'Accuracy: {accuracy:.2f}')
print ()

precision, recall, f1_score, _ = precision_recall_fscore_support(y_test, y_pred)

for i, v in enumerate(['p1', 'p2', 'p3', 'p4']):
    print(f"Class {v}:")
    print(f"Precision: {precision[i]}")
    print(f"Recall: {recall[i]}")
    print(f"F1 Score: {f1_score[i]}")
    print()
# Out:
# Accuracy: 0.77
#
# Class p1:
# Precision: 0.8167202572347267
# Recall: 0.768920282542886
# F1 Score: 0.7920997920997921
#
# Class p2:
# Precision: 0.8246471226927253
# Recall: 0.9119471683009805
# F1 Score: 0.8661028223890526
#
# Class p3:
# Precision: 0.43196004993757803
# Recall: 0.26947040498442365
# F1 Score: 0.33189448441247005
#
# Class p4:
# Precision: 0.7269230769230769
# Recall: 0.7354085603112841
# F1 Score: 0.7311411992263056

# %%
# 3. Decision Tree
from sklearn.tree import DecisionTreeClassifier

y = df_encoded['Approved_Flag']
x = df_encoded. drop ( ['Approved_Flag'], axis = 1 )

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

dt_model = DecisionTreeClassifier(max_depth=20, min_samples_split=10)
dt_model.fit(x_train, y_train)
y_pred = dt_model.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print ()
print(f"Accuracy: {accuracy:.2f}")
print ()

precision, recall, f1_score, _ = precision_recall_fscore_support(y_test, y_pred)

for i, v in enumerate(['p1', 'p2', 'p3', 'p4']):
    print(f"Class {v}:")
    print(f"Precision: {precision[i]}")
    print(f"Recall: {recall[i]}")
    print(f"F1 Score: {f1_score[i]}")
    print()
# Out:
# Accuracy: 0.71
#
# Class p1:
# Precision: 0.7306910569105691
# Recall: 0.7255297679112008
# F1 Score: 0.7281012658227848
#
# Class p2:
# Precision: 0.8097197726827357
# Recall: 0.8268961376826096
# F1 Score: 0.8182178217821782
#
# Class p3:
# Precision: 0.3364406779661017
# Recall: 0.309190031152648
# F1 Score: 0.3222402597402597
#
# Class p4:
# Precision: 0.6321393998063891
# Recall: 0.6352140077821011
# F1 Score: 0.633672974284328

# %%
# Random Forest = 0.76
# Xgboost = 0.77
# Decision Tree = 0.71

# %%
# Accuracy score , xgboost is better
# Now we will further finetune it
# HP tunning
# feature engineering - -scaling , graph

# %%
# Hyperparameter tuning for xgboost
# define the hyperparameter grid

# %%
param_grid ={
    'colsample_bytree': [0.7, 0.8, 0.9],
    'learning_rate': [ 0.1,0.5, 1],
    'max_depth': [2, 3, 4  ],
    'n_estimators': [ 100, 200,  300, 400],
    'alpha': [1,5, 10]

}

# %%
# loop through each combination of hyperparamter
# Assuming these are initialized before the loop
index = 0
answer_grid = {
    'combination': [],
    'train_accuracy': [],
    'test_accuracy': [],
    'colsample_bytree': [],
    'learning_rate': [],
    'max_depth': [],
    'n_estimators': [],
    'alpha': []
}

label_encoder = LabelEncoder()

# %%
x = df_encoded.drop(['Approved_Flag'], axis=1)
y = df_encoded['Approved_Flag']
y = label_encoder.fit_transform(y)

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
best_hyperparameter = []
# Loop through each combination of hyperparameters
for colsample_bytree in param_grid['colsample_bytree']:
    for learning_rate in param_grid['learning_rate']:
        for max_depth in param_grid['max_depth']:
            for n_estimators in param_grid['n_estimators']:
                for alpha in param_grid['alpha']:
                    index += 1
                    model = xgb.XGBClassifier(
                        objective='multi:softmax',
                        num_class=4,
                        colsample_bytree = colsample_bytree,
                        learning_rate = learning_rate,
                        max_depth = max_depth,
                        n_estimators = n_estimators,
                        alpha =  alpha
                    )


                    model.fit(x_train, y_train)
                    y_pred_train = model.predict(x_train)
                    y_pred_test = model.predict(x_test)

                    train_accuracy = accuracy_score(y_train, y_pred_train)
                    test_accuracy = accuracy_score(y_test, y_pred_test)

                    # Include into the lists
                    answer_grid['combination'].append(index)
                    answer_grid['train_accuracy'].append(train_accuracy)
                    answer_grid['test_accuracy'].append(test_accuracy)
                    answer_grid['colsample_bytree'].append(colsample_bytree)
                    answer_grid['learning_rate'].append(learning_rate)
                    answer_grid['max_depth'].append(max_depth)
                    answer_grid['n_estimators'].append(n_estimators)
                    answer_grid['alpha'].append(alpha)
                    
                    if train_accuracy > 0.8 and test_accuracy > 0.75:
                        
                        best_hyperparameter.append( {
                            'Sr.NO': index,
                            'Train accuracy': train_accuracy,
                            'Test accuracy' : test_accuracy,
                            'Colsample bytree':colsample_bytree,
                            'Learning rate':learning_rate,
                            'Max depth':max_depth,
                            'N estimators':n_estimators,
                            'Alpha':alpha
                        })
                        
                        
                        
                        # Print the result for this combination
                        print(f"Combination {index}:")
                        print(f"Colsample_bytree: {colsample_bytree}, learning_rate: {learning_rate}, max_depth: {max_depth}, alpha: {alpha}, n_estimators: {n_estimators}")
                        print(f"Train Accuracy: {train_accuracy:.4f}")
                        print(f"Test Accuracy: {test_accuracy:.4f}")
                        print('--' * 40)
# Out:
# Combination 22:
# Colsample_bytree: 0.7, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 400
# Train Accuracy: 0.8069
# Test Accuracy: 0.7792
# --------------------------------------------------------------------------------
# Combination 23:
# Colsample_bytree: 0.7, learning_rate: 0.1, max_depth: 3, alpha: 5, n_estimators: 400
# Train Accuracy: 0.8017
# Test Accuracy: 0.7788
# --------------------------------------------------------------------------------
# Combination 28:
# Colsample_bytree: 0.7, learning_rate: 0.1, max_depth: 4, alpha: 1, n_estimators: 200
# Train Accuracy: 0.8081
# Test Accuracy: 0.7778
# --------------------------------------------------------------------------------
# Combination 29:
# Colsample_bytree: 0.7, learning_rate: 0.1, max_depth: 4, alpha: 5, n_estimators: 200
# Train Accuracy: 0.8033
# Test Accuracy: 0.7772
# --------------------------------------------------------------------------------
# Combination 31:
# Colsample_bytree: 0.7, learning_rate: 0.1, max_depth: 4, alpha: 1, n_estimators: 300
# Train Accuracy: 0.8197
# Test Accuracy: 0.7778
# --------------------------------------------------------------------------------
# Combination 32:
# Colsample_bytree: 0.7, learning_rate: 0.1, max_depth: 4, alpha: 5, n_estimators: 300
# Train Accuracy: 0.8128
# Test Accuracy: 0.7771
# --------------------------------------------------------------------------------
# Combination 33:
# Colsample_bytree: 0.7, learning_rate: 0.1, max_depth: 4, alpha: 10, n_estimators: 300
# Train Accuracy: 0.8058
# Test Accuracy: 0.7760
# --------------------------------------------------------------------------------
# Combination 34:
# Colsample_bytree: 0.7, learning_rate: 0.1, max_depth: 4, alpha: 1, n_estimators: 400
# Train Accuracy: 0.8302
# Test Accuracy: 0.7784
# --------------------------------------------------------------------------------
# Combination 35:
# Colsample_bytree: 0.7, learning_rate: 0.1, max_depth: 4, alpha: 5, n_estimators: 400
# Train Accuracy: 0.8210
# Test Accuracy: 0.7770
# --------------------------------------------------------------------------------
# Combination 36:
# Colsample_bytree: 0.7, learning_rate: 0.1, max_depth: 4, alpha: 10, n_estimators: 400
# Train Accuracy: 0.8119
# Test Accuracy: 0.7757
# --------------------------------------------------------------------------------
# Combination 40:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 2, alpha: 1, n_estimators: 200
# Train Accuracy: 0.8025
# Test Accuracy: 0.7767
# --------------------------------------------------------------------------------
# Combination 43:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 2, alpha: 1, n_estimators: 300
# Train Accuracy: 0.8097
# Test Accuracy: 0.7760
# --------------------------------------------------------------------------------
# Combination 44:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 2, alpha: 5, n_estimators: 300
# Train Accuracy: 0.8043
# Test Accuracy: 0.7786
# --------------------------------------------------------------------------------
# Combination 46:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 2, alpha: 1, n_estimators: 400
# Train Accuracy: 0.8163
# Test Accuracy: 0.7778
# --------------------------------------------------------------------------------
# Combination 47:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 2, alpha: 5, n_estimators: 400
# Train Accuracy: 0.8084
# Test Accuracy: 0.7780
# --------------------------------------------------------------------------------
# Combination 48:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 2, alpha: 10, n_estimators: 400
# Train Accuracy: 0.8019
# Test Accuracy: 0.7790
# --------------------------------------------------------------------------------
# Combination 49:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.8102
# Test Accuracy: 0.7773
# --------------------------------------------------------------------------------
# Combination 50:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 3, alpha: 5, n_estimators: 100
# Train Accuracy: 0.8063
# Test Accuracy: 0.7765
# --------------------------------------------------------------------------------
# Combination 51:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.8024
# Test Accuracy: 0.7751
# --------------------------------------------------------------------------------
# Combination 52:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 3, alpha: 1, n_estimators: 200
# Train Accuracy: 0.8340
# Test Accuracy: 0.7740
# --------------------------------------------------------------------------------
# Combination 53:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 3, alpha: 5, n_estimators: 200
# Train Accuracy: 0.8239
# Test Accuracy: 0.7757
# --------------------------------------------------------------------------------
# Combination 54:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 3, alpha: 10, n_estimators: 200
# Train Accuracy: 0.8135
# Test Accuracy: 0.7757
# --------------------------------------------------------------------------------
# Combination 55:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 3, alpha: 1, n_estimators: 300
# Train Accuracy: 0.8537
# Test Accuracy: 0.7740
# --------------------------------------------------------------------------------
# Combination 56:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 3, alpha: 5, n_estimators: 300
# Train Accuracy: 0.8357
# Test Accuracy: 0.7733
# --------------------------------------------------------------------------------
# Combination 57:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 3, alpha: 10, n_estimators: 300
# Train Accuracy: 0.8202
# Test Accuracy: 0.7748
# --------------------------------------------------------------------------------
# Combination 58:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 3, alpha: 1, n_estimators: 400
# Train Accuracy: 0.8679
# Test Accuracy: 0.7727
# --------------------------------------------------------------------------------
# Combination 59:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 3, alpha: 5, n_estimators: 400
# Train Accuracy: 0.8464
# Test Accuracy: 0.7716
# --------------------------------------------------------------------------------
# Combination 60:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 3, alpha: 10, n_estimators: 400
# Train Accuracy: 0.8202
# Test Accuracy: 0.7749
# --------------------------------------------------------------------------------
# Combination 61:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 4, alpha: 1, n_estimators: 100
# Train Accuracy: 0.8401
# Test Accuracy: 0.7753
# --------------------------------------------------------------------------------
# Combination 62:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 4, alpha: 5, n_estimators: 100
# Train Accuracy: 0.8270
# Test Accuracy: 0.7747
# --------------------------------------------------------------------------------
# Combination 63:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 4, alpha: 10, n_estimators: 100
# Train Accuracy: 0.8187
# Test Accuracy: 0.7719
# --------------------------------------------------------------------------------
# Combination 64:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 4, alpha: 1, n_estimators: 200
# Train Accuracy: 0.8824
# Test Accuracy: 0.7705
# --------------------------------------------------------------------------------
# Combination 65:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 4, alpha: 5, n_estimators: 200
# Train Accuracy: 0.8607
# Test Accuracy: 0.7727
# --------------------------------------------------------------------------------
# Combination 66:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 4, alpha: 10, n_estimators: 200
# Train Accuracy: 0.8367
# Test Accuracy: 0.7728
# --------------------------------------------------------------------------------
# Combination 67:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 4, alpha: 1, n_estimators: 300
# Train Accuracy: 0.9130
# Test Accuracy: 0.7678
# --------------------------------------------------------------------------------
# Combination 68:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 4, alpha: 5, n_estimators: 300
# Train Accuracy: 0.8829
# Test Accuracy: 0.7711
# --------------------------------------------------------------------------------
# Combination 69:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 4, alpha: 10, n_estimators: 300
# Train Accuracy: 0.8395
# Test Accuracy: 0.7723
# --------------------------------------------------------------------------------
# Combination 70:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 4, alpha: 1, n_estimators: 400
# Train Accuracy: 0.9363
# Test Accuracy: 0.7655
# --------------------------------------------------------------------------------
# Combination 71:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 4, alpha: 5, n_estimators: 400
# Train Accuracy: 0.9000
# Test Accuracy: 0.7699
# --------------------------------------------------------------------------------
# Combination 72:
# Colsample_bytree: 0.7, learning_rate: 0.5, max_depth: 4, alpha: 10, n_estimators: 400
# Train Accuracy: 0.8395
# Test Accuracy: 0.7723
# --------------------------------------------------------------------------------
# Combination 73:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 2, alpha: 1, n_estimators: 100
# Train Accuracy: 0.8018
# Test Accuracy: 0.7757
# --------------------------------------------------------------------------------
# Combination 76:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 2, alpha: 1, n_estimators: 200
# Train Accuracy: 0.8148
# Test Accuracy: 0.7777
# --------------------------------------------------------------------------------
# Combination 77:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 2, alpha: 5, n_estimators: 200
# Train Accuracy: 0.8091
# Test Accuracy: 0.7753
# --------------------------------------------------------------------------------
# Combination 78:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 2, alpha: 10, n_estimators: 200
# Train Accuracy: 0.8018
# Test Accuracy: 0.7776
# --------------------------------------------------------------------------------
# Combination 79:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 2, alpha: 1, n_estimators: 300
# Train Accuracy: 0.8271
# Test Accuracy: 0.7754
# --------------------------------------------------------------------------------
# Combination 80:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 2, alpha: 5, n_estimators: 300
# Train Accuracy: 0.8159
# Test Accuracy: 0.7769
# --------------------------------------------------------------------------------
# Combination 81:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 2, alpha: 10, n_estimators: 300
# Train Accuracy: 0.8045
# Test Accuracy: 0.7778
# --------------------------------------------------------------------------------
# Combination 82:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 2, alpha: 1, n_estimators: 400
# Train Accuracy: 0.8356
# Test Accuracy: 0.7729
# --------------------------------------------------------------------------------
# Combination 83:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 2, alpha: 5, n_estimators: 400
# Train Accuracy: 0.8218
# Test Accuracy: 0.7772
# --------------------------------------------------------------------------------
# Combination 84:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 2, alpha: 10, n_estimators: 400
# Train Accuracy: 0.8045
# Test Accuracy: 0.7778
# --------------------------------------------------------------------------------
# Combination 85:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.8325
# Test Accuracy: 0.7712
# --------------------------------------------------------------------------------
# Combination 86:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 3, alpha: 5, n_estimators: 100
# Train Accuracy: 0.8224
# Test Accuracy: 0.7759
# --------------------------------------------------------------------------------
# Combination 87:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.8114
# Test Accuracy: 0.7753
# --------------------------------------------------------------------------------
# Combination 88:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 200
# Train Accuracy: 0.8666
# Test Accuracy: 0.7723
# --------------------------------------------------------------------------------
# Combination 89:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 3, alpha: 5, n_estimators: 200
# Train Accuracy: 0.8476
# Test Accuracy: 0.7733
# --------------------------------------------------------------------------------
# Combination 90:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 200
# Train Accuracy: 0.8259
# Test Accuracy: 0.7720
# --------------------------------------------------------------------------------
# Combination 91:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 300
# Train Accuracy: 0.8920
# Test Accuracy: 0.7689
# --------------------------------------------------------------------------------
# Combination 92:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 3, alpha: 5, n_estimators: 300
# Train Accuracy: 0.8645
# Test Accuracy: 0.7724
# --------------------------------------------------------------------------------
# Combination 93:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 300
# Train Accuracy: 0.8320
# Test Accuracy: 0.7710
# --------------------------------------------------------------------------------
# Combination 94:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 400
# Train Accuracy: 0.9116
# Test Accuracy: 0.7680
# --------------------------------------------------------------------------------
# Combination 95:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 3, alpha: 5, n_estimators: 400
# Train Accuracy: 0.8770
# Test Accuracy: 0.7659
# --------------------------------------------------------------------------------
# Combination 96:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 400
# Train Accuracy: 0.8320
# Test Accuracy: 0.7710
# --------------------------------------------------------------------------------
# Combination 97:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 4, alpha: 1, n_estimators: 100
# Train Accuracy: 0.8789
# Test Accuracy: 0.7651
# --------------------------------------------------------------------------------
# Combination 98:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 4, alpha: 5, n_estimators: 100
# Train Accuracy: 0.8566
# Test Accuracy: 0.7707
# --------------------------------------------------------------------------------
# Combination 99:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 4, alpha: 10, n_estimators: 100
# Train Accuracy: 0.8364
# Test Accuracy: 0.7704
# --------------------------------------------------------------------------------
# Combination 100:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 4, alpha: 1, n_estimators: 200
# Train Accuracy: 0.9323
# Test Accuracy: 0.7598
# --------------------------------------------------------------------------------
# Combination 101:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 4, alpha: 5, n_estimators: 200
# Train Accuracy: 0.8999
# Test Accuracy: 0.7667
# --------------------------------------------------------------------------------
# Combination 102:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 4, alpha: 10, n_estimators: 200
# Train Accuracy: 0.8589
# Test Accuracy: 0.7683
# --------------------------------------------------------------------------------
# Combination 103:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 4, alpha: 1, n_estimators: 300
# Train Accuracy: 0.9626
# Test Accuracy: 0.7611
# --------------------------------------------------------------------------------
# Combination 104:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 4, alpha: 5, n_estimators: 300
# Train Accuracy: 0.9227
# Test Accuracy: 0.7633
# --------------------------------------------------------------------------------
# Combination 105:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 4, alpha: 10, n_estimators: 300
# Train Accuracy: 0.8676
# Test Accuracy: 0.7651
# --------------------------------------------------------------------------------
# Combination 106:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 4, alpha: 1, n_estimators: 400
# Train Accuracy: 0.9795
# Test Accuracy: 0.7572
# --------------------------------------------------------------------------------
# Combination 107:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 4, alpha: 5, n_estimators: 400
# Train Accuracy: 0.9392
# Test Accuracy: 0.7620
# --------------------------------------------------------------------------------
# Combination 108:
# Colsample_bytree: 0.7, learning_rate: 1, max_depth: 4, alpha: 10, n_estimators: 400
# Train Accuracy: 0.8676
# Test Accuracy: 0.7651
# --------------------------------------------------------------------------------
# Combination 127:
# Colsample_bytree: 0.8, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 300
# Train Accuracy: 0.8005
# Test Accuracy: 0.7775
# --------------------------------------------------------------------------------
# Combination 130:
# Colsample_bytree: 0.8, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 400
# Train Accuracy: 0.8071
# Test Accuracy: 0.7775
# --------------------------------------------------------------------------------
# Combination 131:
# Colsample_bytree: 0.8, learning_rate: 0.1, max_depth: 3, alpha: 5, n_estimators: 400
# Train Accuracy: 0.8029
# Test Accuracy: 0.7784
# --------------------------------------------------------------------------------
# Combination 136:
# Colsample_bytree: 0.8, learning_rate: 0.1, max_depth: 4, alpha: 1, n_estimators: 200
# Train Accuracy: 0.8089
# Test Accuracy: 0.7789
# --------------------------------------------------------------------------------
# Combination 137:
# Colsample_bytree: 0.8, learning_rate: 0.1, max_depth: 4, alpha: 5, n_estimators: 200
# Train Accuracy: 0.8046
# Test Accuracy: 0.7767
# --------------------------------------------------------------------------------
# Combination 138:
# Colsample_bytree: 0.8, learning_rate: 0.1, max_depth: 4, alpha: 10, n_estimators: 200
# Train Accuracy: 0.8005
# Test Accuracy: 0.7775
# --------------------------------------------------------------------------------
# Combination 139:
# Colsample_bytree: 0.8, learning_rate: 0.1, max_depth: 4, alpha: 1, n_estimators: 300
# Train Accuracy: 0.8208
# Test Accuracy: 0.7772
# --------------------------------------------------------------------------------
# Combination 140:
# Colsample_bytree: 0.8, learning_rate: 0.1, max_depth: 4, alpha: 5, n_estimators: 300
# Train Accuracy: 0.8135
# Test Accuracy: 0.7771
# --------------------------------------------------------------------------------
# Combination 141:
# Colsample_bytree: 0.8, learning_rate: 0.1, max_depth: 4, alpha: 10, n_estimators: 300
# Train Accuracy: 0.8073
# Test Accuracy: 0.7775
# --------------------------------------------------------------------------------
# Combination 142:
# Colsample_bytree: 0.8, learning_rate: 0.1, max_depth: 4, alpha: 1, n_estimators: 400
# Train Accuracy: 0.8318
# Test Accuracy: 0.7793
# --------------------------------------------------------------------------------
# Combination 143:
# Colsample_bytree: 0.8, learning_rate: 0.1, max_depth: 4, alpha: 5, n_estimators: 400
# Train Accuracy: 0.8223
# Test Accuracy: 0.7766
# --------------------------------------------------------------------------------
# Combination 144:
# Colsample_bytree: 0.8, learning_rate: 0.1, max_depth: 4, alpha: 10, n_estimators: 400
# Train Accuracy: 0.8145
# Test Accuracy: 0.7763
# --------------------------------------------------------------------------------
# Combination 148:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 2, alpha: 1, n_estimators: 200
# Train Accuracy: 0.8048
# Test Accuracy: 0.7783
# --------------------------------------------------------------------------------
# Combination 151:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 2, alpha: 1, n_estimators: 300
# Train Accuracy: 0.8110
# Test Accuracy: 0.7798
# --------------------------------------------------------------------------------
# Combination 152:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 2, alpha: 5, n_estimators: 300
# Train Accuracy: 0.8052
# Test Accuracy: 0.7775
# --------------------------------------------------------------------------------
# Combination 153:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 2, alpha: 10, n_estimators: 300
# Train Accuracy: 0.8000
# Test Accuracy: 0.7794
# --------------------------------------------------------------------------------
# Combination 154:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 2, alpha: 1, n_estimators: 400
# Train Accuracy: 0.8161
# Test Accuracy: 0.7780
# --------------------------------------------------------------------------------
# Combination 155:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 2, alpha: 5, n_estimators: 400
# Train Accuracy: 0.8093
# Test Accuracy: 0.7776
# --------------------------------------------------------------------------------
# Combination 156:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 2, alpha: 10, n_estimators: 400
# Train Accuracy: 0.8019
# Test Accuracy: 0.7781
# --------------------------------------------------------------------------------
# Combination 157:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.8126
# Test Accuracy: 0.7777
# --------------------------------------------------------------------------------
# Combination 158:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 3, alpha: 5, n_estimators: 100
# Train Accuracy: 0.8066
# Test Accuracy: 0.7761
# --------------------------------------------------------------------------------
# Combination 159:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.8029
# Test Accuracy: 0.7786
# --------------------------------------------------------------------------------
# Combination 160:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 3, alpha: 1, n_estimators: 200
# Train Accuracy: 0.8356
# Test Accuracy: 0.7747
# --------------------------------------------------------------------------------
# Combination 161:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 3, alpha: 5, n_estimators: 200
# Train Accuracy: 0.8252
# Test Accuracy: 0.7780
# --------------------------------------------------------------------------------
# Combination 162:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 3, alpha: 10, n_estimators: 200
# Train Accuracy: 0.8144
# Test Accuracy: 0.7753
# --------------------------------------------------------------------------------
# Combination 163:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 3, alpha: 1, n_estimators: 300
# Train Accuracy: 0.8537
# Test Accuracy: 0.7705
# --------------------------------------------------------------------------------
# Combination 164:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 3, alpha: 5, n_estimators: 300
# Train Accuracy: 0.8384
# Test Accuracy: 0.7737
# --------------------------------------------------------------------------------
# Combination 165:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 3, alpha: 10, n_estimators: 300
# Train Accuracy: 0.8159
# Test Accuracy: 0.7751
# --------------------------------------------------------------------------------
# Combination 166:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 3, alpha: 1, n_estimators: 400
# Train Accuracy: 0.8702
# Test Accuracy: 0.7699
# --------------------------------------------------------------------------------
# Combination 167:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 3, alpha: 5, n_estimators: 400
# Train Accuracy: 0.8492
# Test Accuracy: 0.7729
# --------------------------------------------------------------------------------
# Combination 168:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 3, alpha: 10, n_estimators: 400
# Train Accuracy: 0.8159
# Test Accuracy: 0.7751
# --------------------------------------------------------------------------------
# Combination 169:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 4, alpha: 1, n_estimators: 100
# Train Accuracy: 0.8436
# Test Accuracy: 0.7729
# --------------------------------------------------------------------------------
# Combination 170:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 4, alpha: 5, n_estimators: 100
# Train Accuracy: 0.8321
# Test Accuracy: 0.7739
# --------------------------------------------------------------------------------
# Combination 171:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 4, alpha: 10, n_estimators: 100
# Train Accuracy: 0.8194
# Test Accuracy: 0.7760
# --------------------------------------------------------------------------------
# Combination 172:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 4, alpha: 1, n_estimators: 200
# Train Accuracy: 0.8853
# Test Accuracy: 0.7686
# --------------------------------------------------------------------------------
# Combination 173:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 4, alpha: 5, n_estimators: 200
# Train Accuracy: 0.8635
# Test Accuracy: 0.7719
# --------------------------------------------------------------------------------
# Combination 174:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 4, alpha: 10, n_estimators: 200
# Train Accuracy: 0.8375
# Test Accuracy: 0.7751
# --------------------------------------------------------------------------------
# Combination 175:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 4, alpha: 1, n_estimators: 300
# Train Accuracy: 0.9159
# Test Accuracy: 0.7695
# --------------------------------------------------------------------------------
# Combination 176:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 4, alpha: 5, n_estimators: 300
# Train Accuracy: 0.8869
# Test Accuracy: 0.7698
# --------------------------------------------------------------------------------
# Combination 177:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 4, alpha: 10, n_estimators: 300
# Train Accuracy: 0.8394
# Test Accuracy: 0.7755
# --------------------------------------------------------------------------------
# Combination 178:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 4, alpha: 1, n_estimators: 400
# Train Accuracy: 0.9388
# Test Accuracy: 0.7671
# --------------------------------------------------------------------------------
# Combination 179:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 4, alpha: 5, n_estimators: 400
# Train Accuracy: 0.9027
# Test Accuracy: 0.7653
# --------------------------------------------------------------------------------
# Combination 180:
# Colsample_bytree: 0.8, learning_rate: 0.5, max_depth: 4, alpha: 10, n_estimators: 400
# Train Accuracy: 0.8394
# Test Accuracy: 0.7755
# --------------------------------------------------------------------------------
# Combination 181:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 2, alpha: 1, n_estimators: 100
# Train Accuracy: 0.8018
# Test Accuracy: 0.7759
# --------------------------------------------------------------------------------
# Combination 184:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 2, alpha: 1, n_estimators: 200
# Train Accuracy: 0.8167
# Test Accuracy: 0.7765
# --------------------------------------------------------------------------------
# Combination 185:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 2, alpha: 5, n_estimators: 200
# Train Accuracy: 0.8092
# Test Accuracy: 0.7737
# --------------------------------------------------------------------------------
# Combination 186:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 2, alpha: 10, n_estimators: 200
# Train Accuracy: 0.8024
# Test Accuracy: 0.7772
# --------------------------------------------------------------------------------
# Combination 187:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 2, alpha: 1, n_estimators: 300
# Train Accuracy: 0.8280
# Test Accuracy: 0.7720
# --------------------------------------------------------------------------------
# Combination 188:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 2, alpha: 5, n_estimators: 300
# Train Accuracy: 0.8167
# Test Accuracy: 0.7767
# --------------------------------------------------------------------------------
# Combination 189:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 2, alpha: 10, n_estimators: 300
# Train Accuracy: 0.8057
# Test Accuracy: 0.7769
# --------------------------------------------------------------------------------
# Combination 190:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 2, alpha: 1, n_estimators: 400
# Train Accuracy: 0.8380
# Test Accuracy: 0.7712
# --------------------------------------------------------------------------------
# Combination 191:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 2, alpha: 5, n_estimators: 400
# Train Accuracy: 0.8218
# Test Accuracy: 0.7760
# --------------------------------------------------------------------------------
# Combination 192:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 2, alpha: 10, n_estimators: 400
# Train Accuracy: 0.8062
# Test Accuracy: 0.7757
# --------------------------------------------------------------------------------
# Combination 193:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.8336
# Test Accuracy: 0.7728
# --------------------------------------------------------------------------------
# Combination 194:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 3, alpha: 5, n_estimators: 100
# Train Accuracy: 0.8245
# Test Accuracy: 0.7727
# --------------------------------------------------------------------------------
# Combination 195:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.8152
# Test Accuracy: 0.7749
# --------------------------------------------------------------------------------
# Combination 196:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 200
# Train Accuracy: 0.8671
# Test Accuracy: 0.7690
# --------------------------------------------------------------------------------
# Combination 197:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 3, alpha: 5, n_estimators: 200
# Train Accuracy: 0.8482
# Test Accuracy: 0.7704
# --------------------------------------------------------------------------------
# Combination 198:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 200
# Train Accuracy: 0.8286
# Test Accuracy: 0.7714
# --------------------------------------------------------------------------------
# Combination 199:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 300
# Train Accuracy: 0.8949
# Test Accuracy: 0.7666
# --------------------------------------------------------------------------------
# Combination 200:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 3, alpha: 5, n_estimators: 300
# Train Accuracy: 0.8656
# Test Accuracy: 0.7700
# --------------------------------------------------------------------------------
# Combination 201:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 300
# Train Accuracy: 0.8307
# Test Accuracy: 0.7722
# --------------------------------------------------------------------------------
# Combination 202:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 400
# Train Accuracy: 0.9141
# Test Accuracy: 0.7639
# --------------------------------------------------------------------------------
# Combination 203:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 3, alpha: 5, n_estimators: 400
# Train Accuracy: 0.8789
# Test Accuracy: 0.7684
# --------------------------------------------------------------------------------
# Combination 204:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 400
# Train Accuracy: 0.8307
# Test Accuracy: 0.7722
# --------------------------------------------------------------------------------
# Combination 205:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 4, alpha: 1, n_estimators: 100
# Train Accuracy: 0.8828
# Test Accuracy: 0.7630
# --------------------------------------------------------------------------------
# Combination 206:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 4, alpha: 5, n_estimators: 100
# Train Accuracy: 0.8608
# Test Accuracy: 0.7710
# --------------------------------------------------------------------------------
# Combination 207:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 4, alpha: 10, n_estimators: 100
# Train Accuracy: 0.8388
# Test Accuracy: 0.7710
# --------------------------------------------------------------------------------
# Combination 208:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 4, alpha: 1, n_estimators: 200
# Train Accuracy: 0.9380
# Test Accuracy: 0.7608
# --------------------------------------------------------------------------------
# Combination 209:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 4, alpha: 5, n_estimators: 200
# Train Accuracy: 0.9028
# Test Accuracy: 0.7666
# --------------------------------------------------------------------------------
# Combination 210:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 4, alpha: 10, n_estimators: 200
# Train Accuracy: 0.8636
# Test Accuracy: 0.7682
# --------------------------------------------------------------------------------
# Combination 211:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 4, alpha: 1, n_estimators: 300
# Train Accuracy: 0.9670
# Test Accuracy: 0.7573
# --------------------------------------------------------------------------------
# Combination 212:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 4, alpha: 5, n_estimators: 300
# Train Accuracy: 0.9278
# Test Accuracy: 0.7635
# --------------------------------------------------------------------------------
# Combination 213:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 4, alpha: 10, n_estimators: 300
# Train Accuracy: 0.8699
# Test Accuracy: 0.7681
# --------------------------------------------------------------------------------
# Combination 214:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 4, alpha: 1, n_estimators: 400
# Train Accuracy: 0.9824
# Test Accuracy: 0.7543
# --------------------------------------------------------------------------------
# Combination 215:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 4, alpha: 5, n_estimators: 400
# Train Accuracy: 0.9434
# Test Accuracy: 0.7604
# --------------------------------------------------------------------------------
# Combination 216:
# Colsample_bytree: 0.8, learning_rate: 1, max_depth: 4, alpha: 10, n_estimators: 400
# Train Accuracy: 0.8699
# Test Accuracy: 0.7681
# --------------------------------------------------------------------------------
# Combination 235:
# Colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 300
# Train Accuracy: 0.8023
# Test Accuracy: 0.7777
# --------------------------------------------------------------------------------
# Combination 238:
# Colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 400
# Train Accuracy: 0.8070
# Test Accuracy: 0.7775
# --------------------------------------------------------------------------------
# Combination 239:
# Colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 3, alpha: 5, n_estimators: 400
# Train Accuracy: 0.8030
# Test Accuracy: 0.7780
# --------------------------------------------------------------------------------
# Combination 244:
# Colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 4, alpha: 1, n_estimators: 200
# Train Accuracy: 0.8101
# Test Accuracy: 0.7787
# --------------------------------------------------------------------------------
# Combination 245:
# Colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 4, alpha: 5, n_estimators: 200
# Train Accuracy: 0.8040
# Test Accuracy: 0.7786
# --------------------------------------------------------------------------------
# Combination 246:
# Colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 4, alpha: 10, n_estimators: 200
# Train Accuracy: 0.8006
# Test Accuracy: 0.7786
# --------------------------------------------------------------------------------
# Combination 247:
# Colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 4, alpha: 1, n_estimators: 300
# Train Accuracy: 0.8221
# Test Accuracy: 0.7753
# --------------------------------------------------------------------------------
# Combination 248:
# Colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 4, alpha: 5, n_estimators: 300
# Train Accuracy: 0.8152
# Test Accuracy: 0.7767
# --------------------------------------------------------------------------------
# Combination 249:
# Colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 4, alpha: 10, n_estimators: 300
# Train Accuracy: 0.8078
# Test Accuracy: 0.7765
# --------------------------------------------------------------------------------
# Combination 250:
# Colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 4, alpha: 1, n_estimators: 400
# Train Accuracy: 0.8326
# Test Accuracy: 0.7757
# --------------------------------------------------------------------------------
# Combination 251:
# Colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 4, alpha: 5, n_estimators: 400
# Train Accuracy: 0.8235
# Test Accuracy: 0.7737
# --------------------------------------------------------------------------------
# Combination 252:
# Colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 4, alpha: 10, n_estimators: 400
# Train Accuracy: 0.8140
# Test Accuracy: 0.7758
# --------------------------------------------------------------------------------
# Combination 256:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 2, alpha: 1, n_estimators: 200
# Train Accuracy: 0.8047
# Test Accuracy: 0.7790
# --------------------------------------------------------------------------------
# Combination 259:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 2, alpha: 1, n_estimators: 300
# Train Accuracy: 0.8115
# Test Accuracy: 0.7784
# --------------------------------------------------------------------------------
# Combination 260:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 2, alpha: 5, n_estimators: 300
# Train Accuracy: 0.8051
# Test Accuracy: 0.7786
# --------------------------------------------------------------------------------
# Combination 261:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 2, alpha: 10, n_estimators: 300
# Train Accuracy: 0.8003
# Test Accuracy: 0.7794
# --------------------------------------------------------------------------------
# Combination 262:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 2, alpha: 1, n_estimators: 400
# Train Accuracy: 0.8173
# Test Accuracy: 0.7781
# --------------------------------------------------------------------------------
# Combination 263:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 2, alpha: 5, n_estimators: 400
# Train Accuracy: 0.8098
# Test Accuracy: 0.7775
# --------------------------------------------------------------------------------
# Combination 264:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 2, alpha: 10, n_estimators: 400
# Train Accuracy: 0.8026
# Test Accuracy: 0.7792
# --------------------------------------------------------------------------------
# Combination 265:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.8127
# Test Accuracy: 0.7783
# --------------------------------------------------------------------------------
# Combination 266:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 3, alpha: 5, n_estimators: 100
# Train Accuracy: 0.8083
# Test Accuracy: 0.7775
# --------------------------------------------------------------------------------
# Combination 267:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.8042
# Test Accuracy: 0.7784
# --------------------------------------------------------------------------------
# Combination 268:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 3, alpha: 1, n_estimators: 200
# Train Accuracy: 0.8351
# Test Accuracy: 0.7793
# --------------------------------------------------------------------------------
# Combination 269:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 3, alpha: 5, n_estimators: 200
# Train Accuracy: 0.8258
# Test Accuracy: 0.7787
# --------------------------------------------------------------------------------
# Combination 270:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 3, alpha: 10, n_estimators: 200
# Train Accuracy: 0.8163
# Test Accuracy: 0.7781
# --------------------------------------------------------------------------------
# Combination 271:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 3, alpha: 1, n_estimators: 300
# Train Accuracy: 0.8543
# Test Accuracy: 0.7763
# --------------------------------------------------------------------------------
# Combination 272:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 3, alpha: 5, n_estimators: 300
# Train Accuracy: 0.8382
# Test Accuracy: 0.7751
# --------------------------------------------------------------------------------
# Combination 273:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 3, alpha: 10, n_estimators: 300
# Train Accuracy: 0.8219
# Test Accuracy: 0.7780
# --------------------------------------------------------------------------------
# Combination 274:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 3, alpha: 1, n_estimators: 400
# Train Accuracy: 0.8705
# Test Accuracy: 0.7718
# --------------------------------------------------------------------------------
# Combination 275:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 3, alpha: 5, n_estimators: 400
# Train Accuracy: 0.8504
# Test Accuracy: 0.7722
# --------------------------------------------------------------------------------
# Combination 276:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 3, alpha: 10, n_estimators: 400
# Train Accuracy: 0.8219
# Test Accuracy: 0.7780
# --------------------------------------------------------------------------------
# Combination 277:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 4, alpha: 1, n_estimators: 100
# Train Accuracy: 0.8433
# Test Accuracy: 0.7727
# --------------------------------------------------------------------------------
# Combination 278:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 4, alpha: 5, n_estimators: 100
# Train Accuracy: 0.8309
# Test Accuracy: 0.7725
# --------------------------------------------------------------------------------
# Combination 279:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 4, alpha: 10, n_estimators: 100
# Train Accuracy: 0.8202
# Test Accuracy: 0.7751
# --------------------------------------------------------------------------------
# Combination 280:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 4, alpha: 1, n_estimators: 200
# Train Accuracy: 0.8862
# Test Accuracy: 0.7689
# --------------------------------------------------------------------------------
# Combination 281:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 4, alpha: 5, n_estimators: 200
# Train Accuracy: 0.8640
# Test Accuracy: 0.7730
# --------------------------------------------------------------------------------
# Combination 282:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 4, alpha: 10, n_estimators: 200
# Train Accuracy: 0.8390
# Test Accuracy: 0.7728
# --------------------------------------------------------------------------------
# Combination 283:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 4, alpha: 1, n_estimators: 300
# Train Accuracy: 0.9180
# Test Accuracy: 0.7646
# --------------------------------------------------------------------------------
# Combination 284:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 4, alpha: 5, n_estimators: 300
# Train Accuracy: 0.8873
# Test Accuracy: 0.7693
# --------------------------------------------------------------------------------
# Combination 285:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 4, alpha: 10, n_estimators: 300
# Train Accuracy: 0.8407
# Test Accuracy: 0.7735
# --------------------------------------------------------------------------------
# Combination 286:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 4, alpha: 1, n_estimators: 400
# Train Accuracy: 0.9398
# Test Accuracy: 0.7639
# --------------------------------------------------------------------------------
# Combination 287:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 4, alpha: 5, n_estimators: 400
# Train Accuracy: 0.9044
# Test Accuracy: 0.7684
# --------------------------------------------------------------------------------
# Combination 288:
# Colsample_bytree: 0.9, learning_rate: 0.5, max_depth: 4, alpha: 10, n_estimators: 400
# Train Accuracy: 0.8407
# Test Accuracy: 0.7735
# --------------------------------------------------------------------------------
# Combination 289:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 2, alpha: 1, n_estimators: 100
# Train Accuracy: 0.8028
# Test Accuracy: 0.7806
# --------------------------------------------------------------------------------
# Combination 292:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 2, alpha: 1, n_estimators: 200
# Train Accuracy: 0.8177
# Test Accuracy: 0.7778
# --------------------------------------------------------------------------------
# Combination 293:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 2, alpha: 5, n_estimators: 200
# Train Accuracy: 0.8094
# Test Accuracy: 0.7776
# --------------------------------------------------------------------------------
# Combination 294:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 2, alpha: 10, n_estimators: 200
# Train Accuracy: 0.8013
# Test Accuracy: 0.7765
# --------------------------------------------------------------------------------
# Combination 295:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 2, alpha: 1, n_estimators: 300
# Train Accuracy: 0.8289
# Test Accuracy: 0.7736
# --------------------------------------------------------------------------------
# Combination 296:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 2, alpha: 5, n_estimators: 300
# Train Accuracy: 0.8170
# Test Accuracy: 0.7760
# --------------------------------------------------------------------------------
# Combination 297:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 2, alpha: 10, n_estimators: 300
# Train Accuracy: 0.8050
# Test Accuracy: 0.7767
# --------------------------------------------------------------------------------
# Combination 298:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 2, alpha: 1, n_estimators: 400
# Train Accuracy: 0.8371
# Test Accuracy: 0.7729
# --------------------------------------------------------------------------------
# Combination 299:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 2, alpha: 5, n_estimators: 400
# Train Accuracy: 0.8222
# Test Accuracy: 0.7752
# --------------------------------------------------------------------------------
# Combination 300:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 2, alpha: 10, n_estimators: 400
# Train Accuracy: 0.8050
# Test Accuracy: 0.7767
# --------------------------------------------------------------------------------
# Combination 301:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.8363
# Test Accuracy: 0.7706
# --------------------------------------------------------------------------------
# Combination 302:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 3, alpha: 5, n_estimators: 100
# Train Accuracy: 0.8259
# Test Accuracy: 0.7710
# --------------------------------------------------------------------------------
# Combination 303:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.8170
# Test Accuracy: 0.7740
# --------------------------------------------------------------------------------
# Combination 304:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 200
# Train Accuracy: 0.8707
# Test Accuracy: 0.7659
# --------------------------------------------------------------------------------
# Combination 305:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 3, alpha: 5, n_estimators: 200
# Train Accuracy: 0.8508
# Test Accuracy: 0.7704
# --------------------------------------------------------------------------------
# Combination 306:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 200
# Train Accuracy: 0.8300
# Test Accuracy: 0.7717
# --------------------------------------------------------------------------------
# Combination 307:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 300
# Train Accuracy: 0.8960
# Test Accuracy: 0.7592
# --------------------------------------------------------------------------------
# Combination 308:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 3, alpha: 5, n_estimators: 300
# Train Accuracy: 0.8681
# Test Accuracy: 0.7663
# --------------------------------------------------------------------------------
# Combination 309:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 300
# Train Accuracy: 0.8355
# Test Accuracy: 0.7707
# --------------------------------------------------------------------------------
# Combination 310:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 3, alpha: 1, n_estimators: 400
# Train Accuracy: 0.9169
# Test Accuracy: 0.7565
# --------------------------------------------------------------------------------
# Combination 311:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 3, alpha: 5, n_estimators: 400
# Train Accuracy: 0.8801
# Test Accuracy: 0.7675
# --------------------------------------------------------------------------------
# Combination 312:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 3, alpha: 10, n_estimators: 400
# Train Accuracy: 0.8355
# Test Accuracy: 0.7707
# --------------------------------------------------------------------------------
# Combination 313:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 4, alpha: 1, n_estimators: 100
# Train Accuracy: 0.8873
# Test Accuracy: 0.7652
# --------------------------------------------------------------------------------
# Combination 314:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 4, alpha: 5, n_estimators: 100
# Train Accuracy: 0.8645
# Test Accuracy: 0.7657
# --------------------------------------------------------------------------------
# Combination 315:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 4, alpha: 10, n_estimators: 100
# Train Accuracy: 0.8420
# Test Accuracy: 0.7687
# --------------------------------------------------------------------------------
# Combination 316:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 4, alpha: 1, n_estimators: 200
# Train Accuracy: 0.9401
# Test Accuracy: 0.7651
# --------------------------------------------------------------------------------
# Combination 317:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 4, alpha: 5, n_estimators: 200
# Train Accuracy: 0.9057
# Test Accuracy: 0.7611
# --------------------------------------------------------------------------------
# Combination 318:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 4, alpha: 10, n_estimators: 200
# Train Accuracy: 0.8673
# Test Accuracy: 0.7664
# --------------------------------------------------------------------------------
# Combination 319:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 4, alpha: 1, n_estimators: 300
# Train Accuracy: 0.9692
# Test Accuracy: 0.7587
# --------------------------------------------------------------------------------
# Combination 320:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 4, alpha: 5, n_estimators: 300
# Train Accuracy: 0.9278
# Test Accuracy: 0.7593
# --------------------------------------------------------------------------------
# Combination 321:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 4, alpha: 10, n_estimators: 300
# Train Accuracy: 0.8700
# Test Accuracy: 0.7657
# --------------------------------------------------------------------------------
# Combination 322:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 4, alpha: 1, n_estimators: 400
# Train Accuracy: 0.9833
# Test Accuracy: 0.7575
# --------------------------------------------------------------------------------
# Combination 323:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 4, alpha: 5, n_estimators: 400
# Train Accuracy: 0.9426
# Test Accuracy: 0.7610
# --------------------------------------------------------------------------------
# Combination 324:
# Colsample_bytree: 0.9, learning_rate: 1, max_depth: 4, alpha: 10, n_estimators: 400
# Train Accuracy: 0.8700
# Test Accuracy: 0.7657
# --------------------------------------------------------------------------------

# %%
hyper = pd.DataFrame(best_hyperparameter)
hyper.shape
# Out:
# (228, 8)

# %%
hyper.to_csv("data_of_hyperparameter.csv", index=False)

# %%
best_hyper = pd.read_csv('data_of_hyperparameter.csv')
# Out:
#      Sr.NO  Train accuracy  Test accuracy  Colsample bytree  Learning rate  \
# 0       22        0.806867       0.779157               0.7            0.1
# 1       23        0.801747       0.778795               0.7            0.1
# 2       28        0.808102       0.777831               0.7            0.1
# 3       29        0.803253       0.777229               0.7            0.1
# 4       31        0.819699       0.777831               0.7            0.1
# ..     ...             ...            ...               ...            ...
# 223    320        0.927831       0.759277               0.9            1.0
# 224    321        0.869970       0.765663               0.9            1.0
# 225    322        0.983343       0.757470               0.9            1.0
# 226    323        0.942620       0.760964               0.9            1.0
# 227    324        0.869970       0.765663               0.9            1.0
#
#      Max depth  N estimators  Alpha
# 0            3           400      1
# 1            3           400      5
# 2            4           200      1
# 3            4           200      5
# 4            4           300      1
# ..         ...           ...    ...
# 223          4           300      5
# 224          4           300     10
# 225          4           400      1
# 226          4           400      5
# 227          4           400     10
#
# [228 rows x 8 columns]

# %%
best_hyper['Test accuracy'].sort_values(ascending=False)
# Out:
# 194    0.780602
# 87     0.779759
# 89     0.779398
# 166    0.779398
# 173    0.779277
#          ...
# 225    0.757470
# 145    0.757349
# 71     0.757229
# 213    0.756506
# 148    0.754337
# Name: Test accuracy, Length: 228, dtype: float64

# %%
# this is our best hyperparameter
best_hyper.iloc[194]
# Out:
# Sr.NO               289.000000
# Train accuracy        0.802771
# Test accuracy         0.780602
# Colsample bytree      0.900000
# Learning rate         1.000000
# Max depth             2.000000
# N estimators        100.000000
# Alpha                 1.000000
# Name: 194, dtype: float64

# %%
X = df_encoded.drop(['Approved_Flag'], axis=1)
y = df_encoded['Approved_Flag']
Y = label_encoder.fit_transform(y)

# %%
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
final_model = xgb.XGBClassifier(
                        objective='multi:softmax',
                        num_class=4,
                        colsample_bytree = 0.9,
                        learning_rate = 1,
                        max_depth = 2,
                        n_estimators = 100,
                        alpha =  1
                    )


final_model.fit(x_train, y_train)
y_pred_train = final_model.predict(x_train)
y_pred_test = final_model.predict(x_test)

train_accuracy = accuracy_score(y_train, y_pred_train)
test_accuracy = accuracy_score(y_test, y_pred_test)
print(train_accuracy)
print(test_accuracy)
# Out:
# 0.8027710843373494
# 0.7806024096385542

# %%
testing_data = pd.read_csv("data_for_testing.csv")
testing_data.shape
# Out:
# (564, 55)

# %%
x = testing_data.drop(['Approved_Flag'], axis=1)
y = testing_data['Approved_Flag']
y = label_encoder.fit_transform(y)

# %%
y_pred = final_model.predict(x)

# %%
accuracy = accuracy_score(y, y_pred)
accuracy
# Out:
# 0.7890070921985816

# %%
# model give same accuracy on unseen data as testing data

# %%
import pickle

model_filename = 'Credit_Risk_Predictor.pkl'


with open(model_filename, 'wb') as file:
    pickle.dump(final_model, file)

print(f"Model saved to {model_filename}")
# Out:
# Model saved to Credit_Risk_Predictor.pkl
